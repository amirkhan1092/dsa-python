# %%
import matplotlib.pyplot as plt
import numpy as np 
import math
import random

# %%
x_axis = np.arange(1, 100)
y_axix = np.sin(x_axis)

plt.figure(1)
plt.subplot(221)
plt.plot(x_axis, y_axix)

plt.figure(2)
plt.subplot(224)
plt.plot(x_axis, y_axix)

plt.show()
